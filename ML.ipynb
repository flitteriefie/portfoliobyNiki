# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('clean_drug_data.csv')
df.head()
# Out:
#         ID        Date      DateType      Age      Sex          Race  \
# 0  14-0273  2014-06-28  DateReported  unknown  unknown       unknown
# 1  13-0102  2013-03-21   DateofDeath     48.0     male         black
# 2  16-0165  2016-03-13   DateofDeath     30.0   female         white
# 3  16-0208  2016-03-31   DateofDeath     23.0     male         white
# 4  13-0052  2013-02-13   DateofDeath     22.0     male  asian, other
#
#    DeathCity DeathCounty                                       COD Heroin  \
# 0    unknown     unknown      acute fent, hydrocod, benzodiazepine     No
# 1    norwalk   fairfield                      cocaine intoxication     No
# 2    danbury     unknown     acute heroin and cocaine intoxication    Yes
# 3  greenwich     unknown  acute fentanyl and morphine intoxication    Yes
# 4  greenwich   fairfield                     fentanyl intoxication     No
#
#    ... Methadone Amphet Tramad Morphine_NotHeroin Hydromorphone    Other  \
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'DateType', 'Age', 'Sex', 'Race', 'DeathCity',
#        'DeathCounty', 'COD', 'Heroin', 'Cocaine', 'Fentanyl',
#        'FentanylAnalogue', 'Oxycodone', 'Oxymorphone', 'Ethanol',
#        'Hydrocodone', 'Benzodiazepine', 'Methadone', 'Amphet', 'Tramad',
#        'Morphine_NotHeroin', 'Hydromorphone', 'Other', 'OpiateNOS',
#        'AnyOpioid', 'MannerofDeath', 'NamedDrug'],
#       dtype='object')

# %%
df['NamedDrug'].unique()
df['NamedDrug'] = df['NamedDrug'].replace(np.nan, 'unknown')

# %%
df.isnull().sum()
# Out:
# ID                    0
# Date                  0
# DateType              0
# Age                   0
# Sex                   0
# Race                  0
# DeathCity             0
# DeathCounty           0
# COD                   0
# Heroin                0
# Cocaine               0
# Fentanyl              0
# FentanylAnalogue      0
# Oxycodone             0
# Oxymorphone           0
# Ethanol               0
# Hydrocodone           0
# Benzodiazepine        0
# Methadone             0
# Amphet                0
# Tramad                0
# Morphine_NotHeroin    0
# Hydromorphone         0
# Other                 0
# OpiateNOS             0
# AnyOpioid             0
# MannerofDeath         0
# NamedDrug             0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
labe = LabelEncoder()
df['Age_Cat'] = labe.fit_transform(df['Age'])
df['Sex_Cat'] = labe.fit_transform(df['Sex'])
df['Race_Cat'] = labe.fit_transform(df['Race'])
df['DeathCity_Cat'] = labe.fit_transform(df['DeathCity'])
df['Heroin_Cat'] = labe.fit_transform(df['Heroin'])
df['Cocaine_Cat'] = labe.fit_transform(df['Cocaine'])
df['Fentanyl_Cat'] = labe.fit_transform(df['Fentanyl'])
df['FentanylAnalogue_Cat'] = labe.fit_transform(df['FentanylAnalogue'])
df['Oxycodone_Cat'] = labe.fit_transform(df['Oxycodone'])
df['Oxymorphone_Cat'] = labe.fit_transform(df['Oxymorphone'])
df['Ethanol_Cat'] = labe.fit_transform(df['Ethanol'])
df['Hydrocodone_Cat'] = labe.fit_transform(df['Hydrocodone'])
df['Benzodiazepine_Cat'] = labe.fit_transform(df['Benzodiazepine'])
df['Methadone_Cat'] = labe.fit_transform(df['Methadone'])
df['Amphet_Cat'] = labe.fit_transform(df['Amphet'])
df['Tramad_Cat'] = labe.fit_transform(df['Tramad'])
df['Morphine_NotHeroin_Cat'] = labe.fit_transform(df['Morphine_NotHeroin'])
df['Hydromorphone_Cat'] = labe.fit_transform(df['Hydromorphone'])
df['Other_Cat'] = labe.fit_transform(df['Other'])
df['OpiateNOS_Cat'] = labe.fit_transform(df['OpiateNOS'])
df['AnyOpioid_Cat'] = labe.fit_transform(df['AnyOpioid'])
df['MannerofDeath_Cat'] = labe.fit_transform(df['MannerofDeath'])
df['NamedDrug_Cat'] = labe.fit_transform(df['NamedDrug'])

# %%
df.columns
# Out:
# Index(['ID', 'Date', 'DateType', 'Age', 'Sex', 'Race', 'DeathCity',
#        'DeathCounty', 'COD', 'Heroin', 'Cocaine', 'Fentanyl',
#        'FentanylAnalogue', 'Oxycodone', 'Oxymorphone', 'Ethanol',
#        'Hydrocodone', 'Benzodiazepine', 'Methadone', 'Amphet', 'Tramad',
#        'Morphine_NotHeroin', 'Hydromorphone', 'Other', 'OpiateNOS',
#        'AnyOpioid', 'MannerofDeath', 'NamedDrug', 'Age_Cat', 'Sex_Cat',
#        'Race_Cat', 'DeathCity_Cat', 'Heroin_Cat', 'Cocaine_Cat',
#        'Fentanyl_Cat', 'FentanylAnalogue_Cat', 'Oxycodone_Cat',
#        'Oxymorphone_Cat', 'Ethanol_Cat', 'Hydrocodone_Cat',
#        'Benzodiazepine_Cat', 'Methadone_Cat', 'Amphet_Cat', 'Tramad_Cat',
#        'Morphine_NotHeroin_Cat', 'Hydromorphone_Cat', 'Other_Cat',
#        'OpiateNOS_Cat', 'AnyOpioid_Cat', 'MannerofDeath_Cat', 'NamedDrug_Cat'],
#       dtype='object')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = df[['Age_Cat', 'Sex_Cat','Race_Cat', 'DeathCity_Cat', 'NamedDrug_Cat',
           'Morphine_NotHeroin_Cat', 'Other_Cat','OpiateNOS_Cat', 'AnyOpioid_Cat', 'MannerofDeath_Cat']]
data.head()
# Out:
#    Age_Cat  Sex_Cat  Race_Cat  DeathCity_Cat  NamedDrug_Cat  \
# 0       65        2         9            190              4
# 1       34        1         2            131              2
# 2       16        0        10             39              6
# 3        9        1        10             68              6
# 4        8        1         1             68              4
#
#    Morphine_NotHeroin_Cat  Other_Cat  OpiateNOS_Cat  AnyOpioid_Cat  \
# 0                       1        102              0              1
# 1                       1        102              0              1
# 2                       1        102              0              2
# 3                       1        102              0              2
# 4                       1        102              0              1
#
#    MannerofDeath_Cat
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0

# %%
clust_data = df[['Age', 'Sex', 'Race', 'COD', 'Other', 'OpiateNOS',
         'AnyOpioid', 'MannerofDeath', 'NamedDrug']]
clust_data.head()
# Out:
#        Age      Sex          Race                                       COD  \
# 0  unknown  unknown       unknown      acute fent, hydrocod, benzodiazepine
# 1     48.0     male         black                      cocaine intoxication
# 2     30.0   female         white     acute heroin and cocaine intoxication
# 3     23.0     male         white  acute fentanyl and morphine intoxication
# 4     22.0     male  asian, other                     fentanyl intoxication
#
#      Other OpiateNOS AnyOpioid MannerofDeath NamedDrug
# 0  unknown        No   Unknown      accident  Fentanyl
# 1  unknown        No   Unknown      accident   Cocaine
# 2  unknown        No       Yes      accident    Heroin
# 3  unknown        No       Yes      accident    Heroin
# 4  unknown        No   Unknown      accident  Fentanyl

# %%
from leven import levenshtein       
import numpy as np
from sklearn.cluster import dbscan
import numpy as np 
import pandas as pd
from scipy import ndimage 
from scipy.cluster import hierarchy 
from scipy.spatial import distance_matrix 
from matplotlib import pyplot as plt 
from sklearn import manifold, datasets 
from sklearn.cluster import AgglomerativeClustering
# %matplotlib inline
import jellyfish as jf

# %%
import scipy.cluster.hierarchy as shc

plt.figure(figsize=(10, 7))
plt.title("Drug Overdose Dendograms")
dend = shc.dendrogram(shc.linkage(data, method='ward'))

# %%
from sklearn.cluster import AgglomerativeClustering

cluster = AgglomerativeClustering(n_clusters=7, affinity='euclidean', linkage='ward')
cluster.fit_predict(data)
# Out:
# array([2, 1, 0, ..., 0, 2, 2], dtype=int64)

# %%
plt.figure(figsize=(10, 7))
plt.scatter(data[:,0], data[:,1], c=cluster.labels_, cmap='rainbow')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-14-9533fbf6c536> in <module>
#       1 plt.figure(figsize=(10, 7))
# ----> 2 plt.scatter(data[:,0], data[:,1], c=cluster.labels_, cmap='rainbow')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2798             if self.columns.nlevels > 1:
#    2799                 return self._getitem_multilevel(key)
# -> 2800             indexer = self.columns.get_loc(key)
#    2801             if is_integer(indexer):
#    2802                 indexer = [indexer]
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    2644                 )
#    2645             try:
# -> 2646                 return self._engine.get_loc(key)
#    2647             except KeyError:
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
x = data.values #returns a numpy array
min_max_scaler = MinMaxScaler()
feature_mtx = min_max_scaler.fit_transform(x)
feature_mtx [0:5]
# Out:
# array([[1.        , 1.        , 0.9       , 0.85585586, 0.30769231,
#         0.2       , 0.98076923, 0.        , 0.5       , 0.        ],
#        [0.52307692, 0.5       , 0.2       , 0.59009009, 0.15384615,
#         0.2       , 0.98076923, 0.        , 0.5       , 0.        ],
#        [0.24615385, 0.        , 1.        , 0.17567568, 0.46153846,
#         0.2       , 0.98076923, 0.        , 1.        , 0.        ],
#        [0.13846154, 0.5       , 1.        , 0.30630631, 0.46153846,
#         0.2       , 0.98076923, 0.        , 1.        , 0.        ],
#        [0.12307692, 0.5       , 0.1       , 0.30630631, 0.30769231,
#         0.2       , 0.98076923, 0.        , 0.5       , 0.        ]])

# %%
dist_matrix = distance_matrix(feature_mtx,feature_mtx) 
print(dist_matrix)
# Out:
# [[0.         1.03041531 1.52138021 ... 1.25083881 0.88008228 1.01774046]
#  [1.03041531 0.         1.21782604 ... 1.11045047 0.92925905 1.06255039]
#  [1.52138021 1.21782604 0.         ... 0.5        1.07772065 0.87469757]
#  ...
#  [1.25083881 1.11045047 0.5        ... 0.         0.95471556 0.71770178]
#  [0.88008228 0.92925905 1.07772065 ... 0.95471556 0.         0.52937962]
#  [1.01774046 1.06255039 0.87469757 ... 0.71770178 0.52937962 0.        ]]

# %%
agglom = AgglomerativeClustering(n_clusters = 7, linkage = 'complete')
agglom.fit(feature_mtx)
agglom.labels_
# Out:
# array([1, 0, 1, ..., 1, 1, 1], dtype=int64)

# %%
data['cluster_'] = agglom.labels_
data.head()
# Out:
# C:\Users\sznik\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#    Age_Cat  Sex_Cat  Race_Cat  DeathCity_Cat  NamedDrug_Cat  \
# 0       65        2         9            190              4
# 1       34        1         2            131              2
# 2       16        0        10             39              6
# 3        9        1        10             68              6
# 4        8        1         1             68              4
#
#    Morphine_NotHeroin_Cat  Other_Cat  OpiateNOS_Cat  AnyOpioid_Cat  \
# 0                       1        102              0              1
# ...

# %%
plt.figure(figsize=(10, 7))
plt.scatter(data.iloc[:,0], data.iloc[:,1], c=data['cluster_'], cmap='rainbow')

# %%
data.groupby(['cluster_'])['cluster_'].count()
# Out:
# cluster_
# 0     870
# 1    3495
# 2     411
# 3      19
# 4     220
# 5      69
# 6      19
# Name: cluster_, dtype: int64

# %%
agg_data = data.groupby(['cluster_'])['Age_Cat', 'Sex_Cat','Race_Cat', 'DeathCity_Cat', 'NamedDrug_Cat',
                                     'Morphine_NotHeroin_Cat', 'Other_Cat','OpiateNOS_Cat', 'AnyOpioid_Cat', 'MannerofDeath_Cat'].mean()
agg_data
# Out:
# C:\Users\sznik\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#             Age_Cat   Sex_Cat  Race_Cat  DeathCity_Cat  NamedDrug_Cat  \
# cluster_
# 0         29.124138  0.759770  3.860920      93.354023       4.836782
# 1         26.896137  0.757940  9.822890     110.370243       4.866667
# 2         33.352798  0.605839  9.982968     113.206813       9.048662
# 3         34.842105  0.947368  8.368421     116.315789       6.000000
# 4         28.913636  0.686364  9.377273     106.704545       5.563636
# 5         30.898551  0.579710  9.391304     113.753623       4.072464
# 6         29.947368  0.842105  8.263158      78.736842      12.684211
#
#           Morphine_NotHeroin_Cat   Other_Cat  OpiateNOS_Cat  AnyOpioid_Cat  \
# cluster_
# ...

# %%
import matplotlib.cm as cm
n_clusters = max(agglom.labels_)+1
colors = cm.rainbow(np.linspace(0, 1, n_clusters))
cluster_labels = list(range(0, n_clusters))

# Create a figure of size 6 inches by 4 inches.
plt.figure(figsize=(50,50))

#plt.figure(figsize=(50,50))
for color, label in zip(colors, cluster_labels):
    subset = agg_data.loc[(label,),]
    for i in subset.index:
        plt.text(subset.loc[i][0]+5, subset.loc[i][2], 'Age_Cat='+str(int(i)) + ', Sex_Cat='+str(int(subset.loc[i][3]))+'k')
    plt.scatter(subset.Race_Cat, subset.DeathCity_Cat, s=subset.Age_Cat*20, c=color, label='cluster'+str(label))
plt.legend()
plt.title('Clusters')
plt.xlabel('??')
plt.ylabel('?')
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# ...
